# %%
#Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

#Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
#Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#Create a list for holding the cities.
cities = []

#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
#Print the city count to confirm sufficient count.
len(cities)
# Out:
# 766

# %%
#Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create an empty list to hold the weather data.
city_data = []
#Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters.
record_count = 1
set_count = 1

#Loop through all the cities in our list.
for i, city in enumerate(cities):

    #Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    #Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    #Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    #Add 1 to the record count.
    record_count += 1
    
#Run an API request for each of the cities.
    try:
        #Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        #Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        #Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

#If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

#Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | buraydah
# Processing Record 3 of Set 1 | longyearbyen
# Processing Record 4 of Set 1 | coron
# Processing Record 5 of Set 1 | qaanaaq
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | huilong
# Processing Record 8 of Set 1 | saint-francois
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | hanover
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | cherskiy
# Processing Record 13 of Set 1 | isangel
# Processing Record 14 of Set 1 | pampas
# Processing Record 15 of Set 1 | tiksi
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | sur
# Processing Record 18 of Set 1 | kodiak
# Processing Record 19 of Set 1 | coos bay
# Processing Record 20 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 1 | touros
# Processing Record 22 of Set 1 | tres arroyos
# Processing Record 23 of Set 1 | grindavik
# Processing Record 24 of Set 1 | tahlequah
# Processing Record 25 of Set 1 | bahia blanca
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | hilo
# Processing Record 28 of Set 1 | khatanga
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | howard springs
# Processing Record 31 of Set 1 | faanui
# Processing Record 32 of Set 1 | los llanos de aridane
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | upernavik
# Processing Record 35 of Set 1 | bluff
# Processing Record 36 of Set 1 | payo
# Processing Record 37 of Set 1 | paragominas
# Processing Record 38 of Set 1 | vangaindrano
# Processing Record 39 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 1 | inirida
# Processing Record 41 of Set 1 | salisbury
# Processing Record 42 of Set 1 | tasiilaq
# Processing Record 43 of Set 1 | anadyr
# Processing Record 44 of Set 1 | avarua
# Processing Record 45 of Set 1 | bredasdorp
# Processing Record 46 of Set 1 | georgetown
# Processing Record 47 of Set 1 | mahajanga
# Processing Record 48 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 1 | san cristobal
# Processing Record 50 of Set 1 | vila franca do campo
# Processing Record 1 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 2 | pitimbu
# Processing Record 3 of Set 2 | atuona
# Processing Record 4 of Set 2 | lompoc
# Processing Record 5 of Set 2 | valleyview
# Processing Record 6 of Set 2 | eregli
# Processing Record 7 of Set 2 | dudinka
# Processing Record 8 of Set 2 | saint-philippe
# Processing Record 9 of Set 2 | ayagoz
# Processing Record 10 of Set 2 | strezhevoy
# Processing Record 11 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 2 | roald
# Processing Record 13 of Set 2 | half moon bay
# Processing Record 14 of Set 2 | vao
# Processing Record 15 of Set 2 | kajaani
# Processing Record 16 of Set 2 | sinnamary
# Processing Record 17 of Set 2 | kavaratti
# Processing Record 18 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 2 | saskylakh
# Processing Record 20 of Set 2 | iqaluit
# Processing Record 21 of Set 2 | chokurdakh
# Processing Record 22 of Set 2 | ambilobe
# Processing Record 23 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 24 of Set 2 | clyde river
# Processing Record 25 of Set 2 | ishigaki
# Processing Record 26 of Set 2 | ust-nera
# Processing Record 27 of Set 2 | kavieng
# Processing Record 28 of Set 2 | yumen
# Processing Record 29 of Set 2 | coahuayana
# Processing Record 30 of Set 2 | airai
# Processing Record 31 of Set 2 | tursunzoda
# Processing Record 32 of Set 2 | salalah
# Processing Record 33 of Set 2 | portland
# Processing Record 34 of Set 2 | honiara
# Processing Record 35 of Set 2 | albany
# Processing Record 36 of Set 2 | kapiri mposhi
# Processing Record 37 of Set 2 | east london
# Processing Record 38 of Set 2 | butaritari
# Processing Record 39 of Set 2 | port elizabeth
# Processing Record 40 of Set 2 | carnarvon
# Processing Record 41 of Set 2 | chumphon
# Processing Record 42 of Set 2 | scottsburgh
# City not found. Skipping...
# Processing Record 43 of Set 2 | castro
# Processing Record 44 of Set 2 | kruisfontein
# Processing Record 45 of Set 2 | sladkovo
# Processing Record 46 of Set 2 | tuatapere
# Processing Record 47 of Set 2 | geraldton
# Processing Record 48 of Set 2 | nikolskoye
# Processing Record 49 of Set 2 | thompson
# Processing Record 50 of Set 2 | angostura
# Processing Record 1 of Set 3 | massakory
# Processing Record 2 of Set 3 | jonuta
# Processing Record 3 of Set 3 | katsuura
# Processing Record 4 of Set 3 | jamestown
# Processing Record 5 of Set 3 | cabedelo
# Processing Record 6 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 3 | torbay
# Processing Record 8 of Set 3 | abong mbang
# Processing Record 9 of Set 3 | tuktoyaktuk
# Processing Record 10 of Set 3 | micco
# Processing Record 11 of Set 3 | ixtapa
# Processing Record 12 of Set 3 | leningradskiy
# Processing Record 13 of Set 3 | mbandaka
# Processing Record 14 of Set 3 | ribeira grande
# Processing Record 15 of Set 3 | cape town
# Processing Record 16 of Set 3 | turukhansk
# Processing Record 17 of Set 3 | arlit
# Processing Record 18 of Set 3 | san quintin
# Processing Record 19 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 3 | puerto cabezas
# Processing Record 21 of Set 3 | chuy
# Processing Record 22 of Set 3 | tres lagoas
# Processing Record 23 of Set 3 | obo
# Processing Record 24 of Set 3 | kaitangata
# Processing Record 25 of Set 3 | hamilton
# Processing Record 26 of Set 3 | garissa
# Processing Record 27 of Set 3 | vestmannaeyjar
# Processing Record 28 of Set 3 | bengkulu
# Processing Record 29 of Set 3 | palmer
# Processing Record 30 of Set 3 | yulara
# Processing Record 31 of Set 3 | alofi
# Processing Record 32 of Set 3 | zhaotong
# Processing Record 33 of Set 3 | banepa
# Processing Record 34 of Set 3 | kenai
# Processing Record 35 of Set 3 | magistralnyy
# Processing Record 36 of Set 3 | port blair
# Processing Record 37 of Set 3 | hithadhoo
# Processing Record 38 of Set 3 | coquimbo
# Processing Record 39 of Set 3 | rikitea
# Processing Record 40 of Set 3 | bowen
# Processing Record 41 of Set 3 | port antonio
# Processing Record 42 of Set 3 | luba
# Processing Record 43 of Set 3 | paso del macho
# Processing Record 44 of Set 3 | codrington
# Processing Record 45 of Set 3 | souillac
# Processing Record 46 of Set 3 | les cayes
# Processing Record 47 of Set 3 | goderich
# Processing Record 48 of Set 3 | sao joao da barra
# Processing Record 49 of Set 3 | barrow
# Processing Record 50 of Set 3 | savalou
# Processing Record 1 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 4 | saldanha
# Processing Record 3 of Set 4 | cayenne
# Processing Record 4 of Set 4 | pokhara
# Processing Record 5 of Set 4 | neyshabur
# Processing Record 6 of Set 4 | port alfred
# Processing Record 7 of Set 4 | hailar
# Processing Record 8 of Set 4 | nanortalik
# Processing Record 9 of Set 4 | svetlogorsk
# Processing Record 10 of Set 4 | nome
# Processing Record 11 of Set 4 | sangar
# Processing Record 12 of Set 4 | kalmunai
# Processing Record 13 of Set 4 | clarence town
# Processing Record 14 of Set 4 | taoudenni
# Processing Record 15 of Set 4 | new norfolk
# Processing Record 16 of Set 4 | khani
# Processing Record 17 of Set 4 | terrace
# Processing Record 18 of Set 4 | cap-aux-meules
# Processing Record 19 of Set 4 | oyek
# Processing Record 20 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 21 of Set 4 | matara
# Processing Record 22 of Set 4 | impfondo
# Processing Record 23 of Set 4 | talpa
# Processing Record 24 of Set 4 | deputatskiy
# Processing Record 25 of Set 4 | decin
# Processing Record 26 of Set 4 | pevek
# Processing Record 27 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 4 | marzuq
# Processing Record 29 of Set 4 | waitati
# Processing Record 30 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 4 | takoradi
# Processing Record 33 of Set 4 | kachiry
# Processing Record 34 of Set 4 | canon city
# Processing Record 35 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 36 of Set 4 | rio gallegos
# Processing Record 37 of Set 4 | nabire
# Processing Record 38 of Set 4 | san juan del sur
# Processing Record 39 of Set 4 | severo-yeniseyskiy
# Processing Record 40 of Set 4 | hasaki
# Processing Record 41 of Set 4 | kotido
# Processing Record 42 of Set 4 | mar del plata
# Processing Record 43 of Set 4 | oriximina
# Processing Record 44 of Set 4 | dikson
# Processing Record 45 of Set 4 | mahebourg
# Processing Record 46 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 4 | poum
# Processing Record 48 of Set 4 | tawkar
# City not found. Skipping...
# Processing Record 49 of Set 4 | wahpeton
# Processing Record 50 of Set 4 | hofn
# Processing Record 1 of Set 5 | yellowknife
# Processing Record 2 of Set 5 | uwayl
# City not found. Skipping...
# Processing Record 3 of Set 5 | severo-kurilsk
# Processing Record 4 of Set 5 | balkhash
# Processing Record 5 of Set 5 | luderitz
# Processing Record 6 of Set 5 | klaksvik
# Processing Record 7 of Set 5 | buala
# Processing Record 8 of Set 5 | korla
# Processing Record 9 of Set 5 | pathankot
# Processing Record 10 of Set 5 | juneau
# Processing Record 11 of Set 5 | lac du bonnet
# Processing Record 12 of Set 5 | jha jha
# Processing Record 13 of Set 5 | karratha
# Processing Record 14 of Set 5 | norman wells
# Processing Record 15 of Set 5 | ternate
# Processing Record 16 of Set 5 | san carlos
# Processing Record 17 of Set 5 | bantou
# Processing Record 18 of Set 5 | vaitape
# Processing Record 19 of Set 5 | visnes
# Processing Record 20 of Set 5 | lloydminster
# Processing Record 21 of Set 5 | benin
# Processing Record 22 of Set 5 | abha
# Processing Record 23 of Set 5 | senador jose porfirio
# Processing Record 24 of Set 5 | suntar
# Processing Record 25 of Set 5 | ende
# Processing Record 26 of Set 5 | venado tuerto
# Processing Record 27 of Set 5 | sakakah
# Processing Record 28 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 29 of Set 5 | bellevue
# Processing Record 30 of Set 5 | sorata
# Processing Record 31 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 5 | makakilo city
# Processing Record 33 of Set 5 | ransang
# Processing Record 34 of Set 5 | bayan
# Processing Record 35 of Set 5 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 36 of Set 5 | hermiston
# Processing Record 37 of Set 5 | asau
# Processing Record 38 of Set 5 | ancud
# Processing Record 39 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 40 of Set 5 | urumqi
# Processing Record 41 of Set 5 | taywarah
# Processing Record 42 of Set 5 | houma
# Processing Record 43 of Set 5 | iquique
# Processing Record 44 of Set 5 | arraial do cabo
# Processing Record 45 of Set 5 | itupiranga
# Processing Record 46 of Set 5 | kloulklubed
# Processing Record 47 of Set 5 | moose factory
# Processing Record 48 of Set 5 | lavrentiya
# Processing Record 49 of Set 5 | hambantota
# Processing Record 50 of Set 5 | santa rita
# Processing Record 1 of Set 6 | hemnesberget
# Processing Record 2 of Set 6 | batouri
# Processing Record 3 of Set 6 | sungairaya
# Processing Record 4 of Set 6 | tamandare
# Processing Record 5 of Set 6 | vila
# Processing Record 6 of Set 6 | lata
# Processing Record 7 of Set 6 | manzhouli
# Processing Record 8 of Set 6 | san patricio
# Processing Record 9 of Set 6 | ugoofaaru
# Processing Record 10 of Set 6 | gavardo
# Processing Record 11 of Set 6 | mutare
# Processing Record 12 of Set 6 | uyaan
# Processing Record 13 of Set 6 | chumikan
# Processing Record 14 of Set 6 | sovetskiy
# Processing Record 15 of Set 6 | poykovskiy
# Processing Record 16 of Set 6 | bilibino
# Processing Record 17 of Set 6 | yucca valley
# Processing Record 18 of Set 6 | manokwari
# Processing Record 19 of Set 6 | rio grande
# Processing Record 20 of Set 6 | bethel
# Processing Record 21 of Set 6 | havre-saint-pierre
# Processing Record 22 of Set 6 | vardo
# Processing Record 23 of Set 6 | tynset
# Processing Record 24 of Set 6 | fairbanks
# Processing Record 25 of Set 6 | suzu
# City not found. Skipping...
# Processing Record 26 of Set 6 | sulangan
# Processing Record 27 of Set 6 | paradwip
# City not found. Skipping...
# Processing Record 28 of Set 6 | cheyenne
# Processing Record 29 of Set 6 | pithoragarh
# Processing Record 30 of Set 6 | batagay-alyta
# Processing Record 31 of Set 6 | tombouctou
# Processing Record 32 of Set 6 | shache
# Processing Record 33 of Set 6 | galgani
# City not found. Skipping...
# Processing Record 34 of Set 6 | aberdeen
# Processing Record 35 of Set 6 | road town
# Processing Record 36 of Set 6 | suf
# Processing Record 37 of Set 6 | araouane
# Processing Record 38 of Set 6 | zhigansk
# Processing Record 39 of Set 6 | chardara
# Processing Record 40 of Set 6 | alappuzha
# Processing Record 41 of Set 6 | sukhobezvodnoye
# Processing Record 42 of Set 6 | te anau
# Processing Record 43 of Set 6 | meulaboh
# Processing Record 44 of Set 6 | vaini
# Processing Record 45 of Set 6 | hovd
# Processing Record 46 of Set 6 | poronaysk
# Processing Record 47 of Set 6 | fort atkinson
# Processing Record 48 of Set 6 | lebu
# Processing Record 49 of Set 6 | rovinj
# Processing Record 50 of Set 6 | lorengau
# Processing Record 1 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 2 of Set 7 | yenagoa
# Processing Record 3 of Set 7 | guerrero negro
# Processing Record 4 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 5 of Set 7 | manaure
# Processing Record 6 of Set 7 | mazatlan
# Processing Record 7 of Set 7 | hami
# Processing Record 8 of Set 7 | ozinki
# Processing Record 9 of Set 7 | kopavogur
# Processing Record 10 of Set 7 | saint george
# Processing Record 11 of Set 7 | marawi
# Processing Record 12 of Set 7 | dunedin
# Processing Record 13 of Set 7 | loubomo
# Processing Record 14 of Set 7 | nenjiang
# Processing Record 15 of Set 7 | hailey
# Processing Record 16 of Set 7 | savannah bight
# Processing Record 17 of Set 7 | maloshuyka
# City not found. Skipping...
# Processing Record 18 of Set 7 | nelson bay
# Processing Record 19 of Set 7 | pindobacu
# Processing Record 20 of Set 7 | bubaque
# Processing Record 21 of Set 7 | muslyumovo
# Processing Record 22 of Set 7 | samarai
# Processing Record 23 of Set 7 | gizo
# Processing Record 24 of Set 7 | loandjili
# Processing Record 25 of Set 7 | neuquen
# Processing Record 26 of Set 7 | erdenet
# Processing Record 27 of Set 7 | tigil
# Processing Record 28 of Set 7 | nehe
# Processing Record 29 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 7 | pisco
# Processing Record 31 of Set 7 | flinders
# Processing Record 32 of Set 7 | piedras negras
# Processing Record 33 of Set 7 | ostrovnoy
# Processing Record 34 of Set 7 | brae
# Processing Record 35 of Set 7 | aksarka
# Processing Record 36 of Set 7 | avera
# Processing Record 37 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 7 | havoysund
# Processing Record 39 of Set 7 | lagoa
# Processing Record 40 of Set 7 | paamiut
# Processing Record 41 of Set 7 | bandar-e lengeh
# Processing Record 42 of Set 7 | darhan
# Processing Record 43 of Set 7 | port hedland
# Processing Record 44 of Set 7 | tefe
# Processing Record 45 of Set 7 | marakkanam
# Processing Record 46 of Set 7 | constitucion
# Processing Record 47 of Set 7 | mount isa
# Processing Record 48 of Set 7 | baherden
# Processing Record 49 of Set 7 | vondrozo
# Processing Record 50 of Set 7 | vostok
# Processing Record 1 of Set 8 | niksic
# Processing Record 2 of Set 8 | newark
# Processing Record 3 of Set 8 | cabo san lucas
# Processing Record 4 of Set 8 | port hawkesbury
# Processing Record 5 of Set 8 | westport
# Processing Record 6 of Set 8 | qorveh
# Processing Record 7 of Set 8 | sosnovka
# Processing Record 8 of Set 8 | sibolga
# Processing Record 9 of Set 8 | aketi
# Processing Record 10 of Set 8 | ardakan
# Processing Record 11 of Set 8 | waipawa
# Processing Record 12 of Set 8 | borama
# City not found. Skipping...
# Processing Record 13 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 8 | provideniya
# Processing Record 15 of Set 8 | bambous virieux
# Processing Record 16 of Set 8 | lincoln
# Processing Record 17 of Set 8 | saint-pierre
# Processing Record 18 of Set 8 | caravelas
# Processing Record 19 of Set 8 | brasilia
# Processing Record 20 of Set 8 | itarema
# Processing Record 21 of Set 8 | rosita
# Processing Record 22 of Set 8 | egvekinot
# Processing Record 23 of Set 8 | sarmanovo
# Processing Record 24 of Set 8 | shubarkuduk
# Processing Record 25 of Set 8 | tacoronte
# Processing Record 26 of Set 8 | carballo
# Processing Record 27 of Set 8 | gribanovskiy
# Processing Record 28 of Set 8 | wattegama
# Processing Record 29 of Set 8 | malatya
# Processing Record 30 of Set 8 | ampanihy
# Processing Record 31 of Set 8 | tezu
# Processing Record 32 of Set 8 | rundu
# Processing Record 33 of Set 8 | kieta
# Processing Record 34 of Set 8 | viedma
# Processing Record 35 of Set 8 | quedlinburg
# Processing Record 36 of Set 8 | ayan
# Processing Record 37 of Set 8 | sikea
# City not found. Skipping...
# Processing Record 38 of Set 8 | new waterford
# Processing Record 39 of Set 8 | oranjemund
# Processing Record 40 of Set 8 | mehamn
# Processing Record 41 of Set 8 | mezen
# Processing Record 42 of Set 8 | atasu
# Processing Record 43 of Set 8 | cidreira
# Processing Record 44 of Set 8 | xichang
# Processing Record 45 of Set 8 | kupang
# Processing Record 46 of Set 8 | ust-omchug
# Processing Record 47 of Set 8 | faisalabad
# Processing Record 48 of Set 8 | wloszczowa
# Processing Record 49 of Set 8 | coihaique
# Processing Record 50 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 1 of Set 9 | hanzhong
# Processing Record 2 of Set 9 | alyangula
# Processing Record 3 of Set 9 | trairi
# Processing Record 4 of Set 9 | robertsport
# Processing Record 5 of Set 9 | san andres
# Processing Record 6 of Set 9 | eyemouth
# Processing Record 7 of Set 9 | bousso
# Processing Record 8 of Set 9 | dickinson
# Processing Record 9 of Set 9 | kattivakkam
# Processing Record 10 of Set 9 | olafsvik
# Processing Record 11 of Set 9 | rapar
# Processing Record 12 of Set 9 | tautira
# Processing Record 13 of Set 9 | riyadh
# Processing Record 14 of Set 9 | alta
# Processing Record 15 of Set 9 | ndouci
# City not found. Skipping...
# Processing Record 16 of Set 9 | kiunga
# Processing Record 17 of Set 9 | vila velha
# Processing Record 18 of Set 9 | quetzaltepec
# City not found. Skipping...
# Processing Record 19 of Set 9 | riverton
# Processing Record 20 of Set 9 | simplicio mendes
# Processing Record 21 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 9 | luganville
# Processing Record 23 of Set 9 | srandakan
# Processing Record 24 of Set 9 | norman
# Processing Record 25 of Set 9 | kahului
# Processing Record 26 of Set 9 | glenwood springs
# Processing Record 27 of Set 9 | owando
# Processing Record 28 of Set 9 | lagos
# Processing Record 29 of Set 9 | gotha
# Processing Record 30 of Set 9 | boende
# Processing Record 31 of Set 9 | kedrovyy
# Processing Record 32 of Set 9 | aguimes
# Processing Record 33 of Set 9 | solnechnyy
# Processing Record 34 of Set 9 | esperance
# Processing Record 35 of Set 9 | byron bay
# Processing Record 36 of Set 9 | cuamba
# Processing Record 37 of Set 9 | katangli
# Processing Record 38 of Set 9 | seaford
# Processing Record 39 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 9 | kosonsoy
# Processing Record 41 of Set 9 | zhob
# Processing Record 42 of Set 9 | isla vista
# Processing Record 43 of Set 9 | umm lajj
# Processing Record 44 of Set 9 | adre
# Processing Record 45 of Set 9 | alugan
# Processing Record 46 of Set 9 | berlevag
# Processing Record 47 of Set 9 | mataram
# Processing Record 48 of Set 9 | ponta do sol
# Processing Record 49 of Set 9 | pangnirtung
# Processing Record 50 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 1 of Set 10 | seka
# Processing Record 2 of Set 10 | narsaq
# Processing Record 3 of Set 10 | namibe
# Processing Record 4 of Set 10 | praia da vitoria
# Processing Record 5 of Set 10 | rorvik
# Processing Record 6 of Set 10 | gazion
# City not found. Skipping...
# Processing Record 7 of Set 10 | henties bay
# Processing Record 8 of Set 10 | polewali
# Processing Record 9 of Set 10 | roebourne
# Processing Record 10 of Set 10 | dingle
# Processing Record 11 of Set 10 | quatre cocos
# Processing Record 12 of Set 10 | ardistan
# City not found. Skipping...
# Processing Record 13 of Set 10 | barmstedt
# Processing Record 14 of Set 10 | ca mau
# Processing Record 15 of Set 10 | high level
# Processing Record 16 of Set 10 | aklavik
# Processing Record 17 of Set 10 | nyalikungu
# Processing Record 18 of Set 10 | scottsbluff
# Processing Record 19 of Set 10 | jamame
# Processing Record 20 of Set 10 | forst
# Processing Record 21 of Set 10 | olinda
# Processing Record 22 of Set 10 | thinadhoo
# Processing Record 23 of Set 10 | harper
# Processing Record 24 of Set 10 | waldheim
# Processing Record 25 of Set 10 | santa isabel do rio negro
# Processing Record 26 of Set 10 | nipawin
# Processing Record 27 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 28 of Set 10 | ningxiang
# Processing Record 29 of Set 10 | dera din panah
# City not found. Skipping...
# Processing Record 30 of Set 10 | victoria
# Processing Record 31 of Set 10 | nantucket
# Processing Record 32 of Set 10 | auki
# Processing Record 33 of Set 10 | bangangte
# Processing Record 34 of Set 10 | odweyne
# Processing Record 35 of Set 10 | saryg-sep
# Processing Record 36 of Set 10 | bemidji
# Processing Record 37 of Set 10 | tecoanapa
# Processing Record 38 of Set 10 | linxia
# Processing Record 39 of Set 10 | sindou
# Processing Record 40 of Set 10 | smithers
# Processing Record 41 of Set 10 | tenenkou
# Processing Record 42 of Set 10 | gamba
# Processing Record 43 of Set 10 | monrovia
# Processing Record 44 of Set 10 | mogadishu
# Processing Record 45 of Set 10 | belyy yar
# Processing Record 46 of Set 10 | hurghada
# Processing Record 47 of Set 10 | constantine
# Processing Record 48 of Set 10 | san pedro
# Processing Record 49 of Set 10 | qasigiannguit
# Processing Record 50 of Set 10 | margate
# Processing Record 1 of Set 11 | taua
# Processing Record 2 of Set 11 | ambulu
# Processing Record 3 of Set 11 | eureka
# Processing Record 4 of Set 11 | atar
# Processing Record 5 of Set 11 | white rock
# Processing Record 6 of Set 11 | kudahuvadhoo
# Processing Record 7 of Set 11 | sant feliu de guixols
# Processing Record 8 of Set 11 | platanos
# Processing Record 9 of Set 11 | puri
# Processing Record 10 of Set 11 | zelenoborskiy
# Processing Record 11 of Set 11 | ketrzyn
# Processing Record 12 of Set 11 | englewood
# Processing Record 13 of Set 11 | najran
# Processing Record 14 of Set 11 | rocha
# Processing Record 15 of Set 11 | chone
# Processing Record 16 of Set 11 | el rodeo
# Processing Record 17 of Set 11 | mercedes
# Processing Record 18 of Set 11 | churapcha
# Processing Record 19 of Set 11 | tevaitoa
# Processing Record 20 of Set 11 | fortuna
# Processing Record 21 of Set 11 | garowe
# Processing Record 22 of Set 11 | kamenka
# Processing Record 23 of Set 11 | talcahuano
# Processing Record 24 of Set 11 | richards bay
# Processing Record 25 of Set 11 | koygorodok
# Processing Record 26 of Set 11 | erzin
# Processing Record 27 of Set 11 | chitral
# Processing Record 28 of Set 11 | ahipara
# Processing Record 29 of Set 11 | sakaiminato
# Processing Record 30 of Set 11 | sahrak
# City not found. Skipping...
# Processing Record 31 of Set 11 | mount gambier
# Processing Record 32 of Set 11 | aitape
# Processing Record 33 of Set 11 | honningsvag
# Processing Record 34 of Set 11 | desbiens
# Processing Record 35 of Set 11 | klyuchi
# Processing Record 36 of Set 11 | tepic
# Processing Record 37 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 38 of Set 11 | camacha
# Processing Record 39 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 11 | coffs harbour
# Processing Record 41 of Set 11 | port pirie
# Processing Record 42 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 11 | nogliki
# Processing Record 44 of Set 11 | noumea
# Processing Record 45 of Set 11 | sao filipe
# Processing Record 46 of Set 11 | morondava
# Processing Record 47 of Set 11 | laguna
# Processing Record 48 of Set 11 | findhorn
# Processing Record 49 of Set 11 | sola
# Processing Record 50 of Set 11 | tucuman
# Processing Record 1 of Set 12 | chipinge
# Processing Record 2 of Set 12 | el real de santa maria
# Processing Record 3 of Set 12 | smiltene
# Processing Record 4 of Set 12 | gualeguay
# Processing Record 5 of Set 12 | zeya
# Processing Record 6 of Set 12 | banda aceh
# Processing Record 7 of Set 12 | shahr-e babak
# Processing Record 8 of Set 12 | colatina
# Processing Record 9 of Set 12 | rawson
# Processing Record 10 of Set 12 | okhotsk
# Processing Record 11 of Set 12 | krasnoselkup
# Processing Record 12 of Set 12 | mana
# Processing Record 13 of Set 12 | adrar
# Processing Record 14 of Set 12 | toftir
# City not found. Skipping...
# Processing Record 15 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 12 | garachine
# Processing Record 17 of Set 12 | binga
# Processing Record 18 of Set 12 | ascoli piceno
# Processing Record 19 of Set 12 | jabiru
# City not found. Skipping...
# Processing Record 20 of Set 12 | rio grande city
# Processing Record 21 of Set 12 | vero beach
# Processing Record 22 of Set 12 | isla mujeres
# Processing Record 23 of Set 12 | muroto
# Processing Record 24 of Set 12 | gravdal
# Processing Record 25 of Set 12 | camacupa
# Processing Record 26 of Set 12 | uglegorsk
# Processing Record 27 of Set 12 | bosaso
# Processing Record 28 of Set 12 | ukiah
# Processing Record 29 of Set 12 | dongsheng
# Processing Record 30 of Set 12 | lerwick
# Processing Record 31 of Set 12 | vilhena
# Processing Record 32 of Set 12 | tsiroanomandidy
# Processing Record 33 of Set 12 | panorama
# Processing Record 34 of Set 12 | brigantine
# Processing Record 35 of Set 12 | ouro preto
# Processing Record 36 of Set 12 | banjar
# Processing Record 37 of Set 12 | mandalgovi
# Processing Record 38 of Set 12 | la seyne-sur-mer
# Processing Record 39 of Set 12 | kosa
# Processing Record 40 of Set 12 | shahrud
# Processing Record 41 of Set 12 | casino
# Processing Record 42 of Set 12 | husavik
# Processing Record 43 of Set 12 | mananjary
# Processing Record 44 of Set 12 | acuna
# City not found. Skipping...
# Processing Record 45 of Set 12 | terenos
# Processing Record 46 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 47 of Set 12 | sorland
# Processing Record 48 of Set 12 | sitka
# Processing Record 49 of Set 12 | bambari
# Processing Record 50 of Set 12 | haukipudas
# Processing Record 1 of Set 13 | willowmore
# Processing Record 2 of Set 13 | praya
# Processing Record 3 of Set 13 | ocos
# Processing Record 4 of Set 13 | bouca
# Processing Record 5 of Set 13 | labuhan
# Processing Record 6 of Set 13 | washougal
# Processing Record 7 of Set 13 | naze
# Processing Record 8 of Set 13 | sassandra
# Processing Record 9 of Set 13 | joshimath
# Processing Record 10 of Set 13 | nara
# Processing Record 11 of Set 13 | ilhabela
# Processing Record 12 of Set 13 | ruteng
# Processing Record 13 of Set 13 | lazo
# Processing Record 14 of Set 13 | peniche
# Processing Record 15 of Set 13 | chernyshevskiy
# Processing Record 16 of Set 13 | faya
# Processing Record 17 of Set 13 | unai
# Processing Record 18 of Set 13 | mayo
# Processing Record 19 of Set 13 | phangnga
# Processing Record 20 of Set 13 | carutapera
# Processing Record 21 of Set 13 | lola
# Processing Record 22 of Set 13 | minab
# Processing Record 23 of Set 13 | mahina
# Processing Record 24 of Set 13 | ambagarh chauki
# Processing Record 25 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 26 of Set 13 | plettenberg bay
# Processing Record 27 of Set 13 | naryan-mar
# Processing Record 28 of Set 13 | evensk
# Processing Record 29 of Set 13 | moshny
# Processing Record 30 of Set 13 | safaga
# Processing Record 31 of Set 13 | nuevo casas grandes
# Processing Record 32 of Set 13 | yeppoon
# Processing Record 33 of Set 13 | khandbari
# Processing Record 34 of Set 13 | acajutla
# Processing Record 35 of Set 13 | tran
# Processing Record 36 of Set 13 | sao felix do xingu
# Processing Record 37 of Set 13 | rum
# Processing Record 38 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 39 of Set 13 | biak
# Processing Record 40 of Set 13 | neryungri
# Processing Record 41 of Set 13 | merauke
# Processing Record 42 of Set 13 | bogorodskoye
# Processing Record 43 of Set 13 | labuan
# Processing Record 44 of Set 13 | novyy urengoy
# Processing Record 45 of Set 13 | katobu
# Processing Record 46 of Set 13 | umea
# Processing Record 47 of Set 13 | tambopata
# Processing Record 48 of Set 13 | karsava
# Processing Record 49 of Set 13 | zhangye
# Processing Record 50 of Set 13 | noyabrsk
# Processing Record 1 of Set 14 | boundiali
# Processing Record 2 of Set 14 | castlegar
# Processing Record 3 of Set 14 | novo aripuana
# Processing Record 4 of Set 14 | catamarca
# Processing Record 5 of Set 14 | podor
# Processing Record 6 of Set 14 | comodoro rivadavia
# Processing Record 7 of Set 14 | sederot
# Processing Record 8 of Set 14 | yar-sale
# Processing Record 9 of Set 14 | charters towers
# Processing Record 10 of Set 14 | toul
# Processing Record 11 of Set 14 | barcelos
# Processing Record 12 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 13 of Set 14 | jiangyou
# Processing Record 14 of Set 14 | tabas
# Processing Record 15 of Set 14 | broken hill
# Processing Record 16 of Set 14 | christchurch
# Processing Record 17 of Set 14 | jacareacanga
# Processing Record 18 of Set 14 | narwar
# Processing Record 19 of Set 14 | malpe
# Processing Record 20 of Set 14 | arman
# Processing Record 21 of Set 14 | irituia
# Processing Record 22 of Set 14 | heiloo
# Processing Record 23 of Set 14 | kolda
# Processing Record 24 of Set 14 | havelock
# Processing Record 25 of Set 14 | tessalit
# Processing Record 26 of Set 14 | trogir
# Processing Record 27 of Set 14 | qaqortoq
# Processing Record 28 of Set 14 | hirara
# Processing Record 29 of Set 14 | beringovskiy
# Processing Record 30 of Set 14 | villanueva de cordoba
# Processing Record 31 of Set 14 | bocana de paiwas
# Processing Record 32 of Set 14 | jinka
# Processing Record 33 of Set 14 | jumla
# Processing Record 34 of Set 14 | sabang
# Processing Record 35 of Set 14 | gat
# Processing Record 36 of Set 14 | bokspits
# City not found. Skipping...
# Processing Record 37 of Set 14 | odoyev
# Processing Record 38 of Set 14 | otane
# Processing Record 39 of Set 14 | kartaly
# Processing Record 40 of Set 14 | launceston
# Processing Record 41 of Set 14 | talara
# Processing Record 42 of Set 14 | samana
# Processing Record 43 of Set 14 | fereydunshahr
# Processing Record 44 of Set 14 | roma
# Processing Record 45 of Set 14 | santa cruz
# Processing Record 46 of Set 14 | duartina
# Processing Record 47 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 48 of Set 14 | parabel
# Processing Record 49 of Set 14 | hobyo
# Processing Record 50 of Set 14 | san vicente
# Processing Record 1 of Set 15 | suzdal
# Processing Record 2 of Set 15 | berezovyy
# Processing Record 3 of Set 15 | pingliang
# Processing Record 4 of Set 15 | jalu
# Processing Record 5 of Set 15 | simao
# Processing Record 6 of Set 15 | srednekolymsk
# Processing Record 7 of Set 15 | taybad
# Processing Record 8 of Set 15 | hudson bay
# Processing Record 9 of Set 15 | senanga
# Processing Record 10 of Set 15 | manturovo
# Processing Record 11 of Set 15 | boa vista
# Processing Record 12 of Set 15 | davenda
# Processing Record 13 of Set 15 | rusape
# Processing Record 14 of Set 15 | grand forks
# Processing Record 15 of Set 15 | pousat
# City not found. Skipping...
# Processing Record 16 of Set 15 | black forest
# Processing Record 17 of Set 15 | zaraza
# Processing Record 18 of Set 15 | along
# Processing Record 19 of Set 15 | yaring
# Processing Record 20 of Set 15 | ewa beach
# Processing Record 21 of Set 15 | ola
# Processing Record 22 of Set 15 | den helder
# Processing Record 23 of Set 15 | huarmey
# Processing Record 24 of Set 15 | nguru
# Processing Record 25 of Set 15 | banmo
# City not found. Skipping...
# Processing Record 26 of Set 15 | innisfail
# Processing Record 27 of Set 15 | san nicolas
# Processing Record 28 of Set 15 | thunder bay
# Processing Record 29 of Set 15 | kuala krai
# City not found. Skipping...
# Processing Record 30 of Set 15 | sarnia
# Processing Record 31 of Set 15 | nioro
# Processing Record 32 of Set 15 | hun
# Processing Record 33 of Set 15 | sorong
# Processing Record 34 of Set 15 | mega
# Processing Record 35 of Set 15 | ponta delgada
# Processing Record 36 of Set 15 | abu kamal
# Processing Record 37 of Set 15 | parsabad
# Processing Record 38 of Set 15 | fare
# Processing Record 39 of Set 15 | farafangana
# Processing Record 40 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 41 of Set 15 | sona
# Processing Record 42 of Set 15 | teguldet
# Processing Record 43 of Set 15 | dekoa
# City not found. Skipping...
# Processing Record 44 of Set 15 | almaznyy
# Processing Record 45 of Set 15 | mampong
# Processing Record 46 of Set 15 | colonelganj
# Processing Record 47 of Set 15 | pandan
# Processing Record 48 of Set 15 | katherine
# Processing Record 49 of Set 15 | hammerfest
# Processing Record 50 of Set 15 | drayton valley
# Processing Record 1 of Set 16 | bonthe
# Processing Record 2 of Set 16 | banamba
# Processing Record 3 of Set 16 | caohai
# Processing Record 4 of Set 16 | camopi
# Processing Record 5 of Set 16 | northam
# Processing Record 6 of Set 16 | praia
# Processing Record 7 of Set 16 | kindu
# Processing Record 8 of Set 16 | safwah
# City not found. Skipping...
# Processing Record 9 of Set 16 | niamtougou
# Processing Record 10 of Set 16 | canutama
# Processing Record 11 of Set 16 | tabou
# Processing Record 12 of Set 16 | borodino
# Processing Record 13 of Set 16 | murgab
# Processing Record 14 of Set 16 | tapaua
# City not found. Skipping...
# Processing Record 15 of Set 16 | lodja
# Processing Record 16 of Set 16 | le passage
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Hermanus -34.4187   19.2345     54.90        58           4
# 1        Buraydah  26.3260   43.9750     88.25        19          67
# 2    Longyearbyen  78.2186   15.6401     24.64        58          20
# 3           Coron  11.9986  120.2043     88.14        60          96
# 4         Qaanaaq  77.4840  -69.3632     22.55        81         100
# 5    Puerto Ayora  -0.7393  -90.3518     74.55        87          22
# 6         Huilong  31.8111  121.6550     67.03        88         100
# 7  Saint-Francois  46.4154    3.9054     47.64        81           0
# 8           Kapaa  22.0752 -159.3190     79.20        67          21
# 9         Hanover  52.3705    9.7332     52.02        94          98
#
#    Wind Speed Country   Current Description
# 0        8.21      ZA             clear sky
# 1        9.40      SA         broken clouds
# 2       10.36      SJ            few clouds
# 3        3.44      PH       overcast clouds
# 4        3.53      GL       overcast clouds
# 5        5.99      EC            few clouds
# 6       13.00      CN  heavy intensity rain
# 7        4.61      FR             clear sky
# 8        1.01      US            few clouds
# 9        6.62      DE       overcast clouds

# %%
#Reorder the columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Hermanus      ZA -34.4187   19.2345     54.90        58           4
# 1        Buraydah      SA  26.3260   43.9750     88.25        19          67
# 2    Longyearbyen      SJ  78.2186   15.6401     24.64        58          20
# 3           Coron      PH  11.9986  120.2043     88.14        60          96
# 4         Qaanaaq      GL  77.4840  -69.3632     22.55        81         100
# 5    Puerto Ayora      EC  -0.7393  -90.3518     74.55        87          22
# 6         Huilong      CN  31.8111  121.6550     67.03        88         100
# 7  Saint-Francois      FR  46.4154    3.9054     47.64        81           0
# 8           Kapaa      US  22.0752 -159.3190     79.20        67          21
# 9         Hanover      DE  52.3705    9.7332     52.02        94          98
#
#    Wind Speed   Current Description
# 0        8.21             clear sky
# 1        9.40         broken clouds
# 2       10.36            few clouds
# 3        3.44       overcast clouds
# 4        3.53       overcast clouds
# 5        5.99            few clouds
# 6       13.00  heavy intensity rain
# 7        4.61             clear sky
# 8        1.01            few clouds
# 9        6.62       overcast clouds

# %%
#Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

#Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
